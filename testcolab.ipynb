# %% [markdown]
# <a href="https://colab.research.google.com/github/kimeungse/colab/blob/main/testcolab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 1
b = 2
c = a + b + 9 + 1
print(c)
# Out:
# 12
